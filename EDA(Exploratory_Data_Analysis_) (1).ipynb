# %%
##EDA >> Exploratory Data analysi
#-- EDA is used to understand the profile of data
# --statical based analysis
#--Graph based analysis
#--automated EDA ex- pandas profiling,D-tale,dabl,sweetViz,datatile





##Different usecases of graphes
# scatter plot>> To understand relation between two variable
#Line chart >> whenever on x axis ,  we have time component
#bar chart >> for categorical data
# count plot >> for categorical data
# pie chart >> for the distribution of different unique classes
# box plot and violin plot >> to determine outlier
# Histogram/distributin >> for continuous data
# heat map >> to understand the co-rrelationship
#Pairplot >> all the numerical relationship in one plot
# join plot >> relationship and distribution of data
#swamplot/relplot >> scaterplot
# lmplot >> regression line

# %% [markdown]
# EDA and Data preparation is different

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('googleplaystore.csv')

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
df.shape
# Out:
# (10841, 13)

# %%
df.tail()
# Out:
#                                                  App             Category  \
# 10836                               Sya9a Maroc - FR               FAMILY
# 10837               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating             Genres      Last Updated         Current Ver  \
# ...

# %%
df.sample()
# Out:
#                                                    App Category  Rating  \
# 7668  Remote | Fire TV | Android TV | KODI | CetusPlay    TOOLS     4.4
#
#      Reviews Size    Installs  Type Price Content Rating Genres  \
# 7668   15911  16M  1,000,000+  Free     0       Everyone  Tools
#
#        Last Updated Current Ver Android Ver
# 7668  June 30, 2018     4.1.8.1  4.1 and up

# %%
df.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews            object
# Size               object
# Installs           object
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
##what is statistical value for  of data
df.describe() ##it will only give numerical by default
 ##insights >> this max value 19 is an outlier, wrong value
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %%
##when we want to take all numerical as well as categorical value then use describe
df.describe(include='all')
# Out:
#            App Category       Rating Reviews                Size    Installs  \
# count    10841    10841  9367.000000   10841               10841       10841
# unique    9660       34          NaN    6002                 462          22
# top     ROBLOX   FAMILY          NaN       0  Varies with device  1,000,000+
# freq         9     1972          NaN     596                1695        1579
# mean       NaN      NaN     4.193338     NaN                 NaN         NaN
# std        NaN      NaN     0.537431     NaN                 NaN         NaN
# min        NaN      NaN     1.000000     NaN                 NaN         NaN
# 25%        NaN      NaN     4.000000     NaN                 NaN         NaN
# 50%        NaN      NaN     4.300000     NaN                 NaN         NaN
# 75%        NaN      NaN     4.500000     NaN                 NaN         NaN
# max        NaN      NaN    19.000000     NaN                 NaN         NaN
#
# ...

# %%
# Data ingestion is the first step of data pipelining
##EDA(data analysis) it is the 2nd step
#Data preprocessing /feature engineering #it is the third step

# %%
#now check is there any duplicate data or not
df[df.duplicated()]
# Out:
#                                                    App      Category  Rating  \
# 229                       Quick PDF Scanner + OCR FREE      BUSINESS     4.2
# 236                                                Box      BUSINESS     4.2
# 239                                 Google My Business      BUSINESS     4.4
# 256                                ZOOM Cloud Meetings      BUSINESS     4.4
# 261                          join.me - Simple Meetings      BUSINESS     4.0
# ...                                                ...           ...     ...
# 8643                    Wunderlist: To-Do List & Tasks  PRODUCTIVITY     4.6
# 8654   TickTick: To Do List with Reminder, Day Planner  PRODUCTIVITY     4.6
# 8658                           ColorNote Notepad Notes  PRODUCTIVITY     4.6
# 10049        Airway Ex - Intubate. Anesthetize. Train.       MEDICAL     4.3
# 10768                                             AAFP       MEDICAL     3.8
#
# ...

# %%
# how many duplicated values
df.duplicated().sum()
# Out:
# 483

# %%
#Now drop the duplicate values
#if you dont drop your duplicate value all your statistical analysis is not make sense here
# df.drop_duplicates(inplace=True)

# %%
##Now check after drop values
df.duplicated().sum()
# Out:
# 483

# %%
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
df.Reviews ##it is the continuous data because there is 159,967 type value
##if you think it is categical the it it will have to value like (1,2,3,4,5)
# Out:
# 0           159
# 1           967
# 2         87510
# 3        215644
# 4           967
#           ...
# 10836        38
# 10837         4
# 10838         3
# 10839       114
# 10840    398307
# Name: Reviews, Length: 10841, dtype: object

# %%
df['Reviews'].dtype ##dtype('O') this is the object column
##then you think its values are look like in continuous value datatype
# but when we check this columns then we occure this is an object datatype
# Out:
# dtype('O')

# %%
# So why it is in string format ?
# >>Now answer is when any one value of this column was string it did convert all the values in string format and now its datatype is showing object here

# %%
df['Reviews'].unique()[:1000]
# Out:
# array(['159', '967', '87510', '215644', '167', '178', '36815', '13791',
#        '121', '13880', '8788', '44829', '4326', '1518', '55', '3632',
#        '27', '194216', '224399', '450', '654', '7699', '61', '118', '192',
#        '20260', '203', '136', '223', '1120', '227', '5035', '1015', '353',
#        '564', '8145', '36639', '158', '591', '117', '176', '295221',
#        '2206', '26', '174531', '1070', '85', '845', '367', '1598', '284',
#        '17057', '129', '542', '10479', '805', '1403', '3971', '534',
#        '7774', '38846', '2431', '6090', '295', '190', '40211', '356',
#        '52530', '116986', '1379', '271920', '736', '7021', '197', '737',
#        '3574', '994', '197136', '142', '15168', '2155', '138', '5414',
#        '21777', '348', '250', '13372', '7880', '3617', '4806', '65786',
#        '31433', '5097', '1754', '2680', '1288', '18900', '49790', '1150',
#        '1739', '32090', '2225', '4369', '8572', '964', '42050', '104',
# ...

# %%
# how we figure it out some perticular value is in string column
# it is my solution
# for i in df['Reviews']:
#   if isinstance(i, str) and i.isalpha():
#     print(i)

#it is another solution
df[~df.Reviews.str.isnumeric()] #due to presence of 3.0M the whole column is convert to be in strin column
# Here str is used to convert this series datapoins to str format and then we can easily access this
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
df_copy = df.copy()

# %%
# df_copy.drop(df_copy.index())
# df_copy.drop(df_copy.index[10472])
df_copy.reset_index(drop=True)
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
# df_copy.drop(df_copy.index[10472],inplace = True)
# df_copy[~df_copy.Reviews.str.isnumeric()]
df_copy[~df_copy['Reviews'].apply(lambda x:x.isnumeric())]
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
df_copy.drop(df_copy.index[10472],inplace=True)

# %%
df['Reviews'].dtype
# Out:
# dtype('O')

# %%
df_copy['Reviews'] = df_copy['Reviews'].astype(int) ##astype is used to convert one datetype to another datatype

# %%
df_copy['Reviews'].dtype
# Out:
# dtype('int64')

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(x= df_copy['Reviews'])
plt.show()

# %%
#drop the null values
# import seaborn as sns
# sns.histplot(df_copy['Reviews'])

# %%
df_copy['Reviews']
# Out:
# 0           159
# 1           967
# 2         87510
# 3        215644
# 4           967
#           ...
# 10836        38
# 10837         4
# 10838         3
# 10839       114
# 10840    398307
# Name: Reviews, Length: 10840, dtype: int64

# %%
df_copy['Size'].unique()
# Out:
# array(['19M', '14M', '8.7M', '25M', '2.8M', '5.6M', '29M', '33M', '3.1M',
#        '28M', '12M', '20M', '21M', '37M', '2.7M', '5.5M', '17M', '39M',
#        '31M', '4.2M', '7.0M', '23M', '6.0M', '6.1M', '4.6M', '9.2M',
#        '5.2M', '11M', '24M', 'Varies with device', '9.4M', '15M', '10M',
#        '1.2M', '26M', '8.0M', '7.9M', '56M', '57M', '35M', '54M', '201k',
#        '3.6M', '5.7M', '8.6M', '2.4M', '27M', '2.5M', '16M', '3.4M',
#        '8.9M', '3.9M', '2.9M', '38M', '32M', '5.4M', '18M', '1.1M',
#        '2.2M', '4.5M', '9.8M', '52M', '9.0M', '6.7M', '30M', '2.6M',
#        '7.1M', '3.7M', '22M', '7.4M', '6.4M', '3.2M', '8.2M', '9.9M',
#        '4.9M', '9.5M', '5.0M', '5.9M', '13M', '73M', '6.8M', '3.5M',
#        '4.0M', '2.3M', '7.2M', '2.1M', '42M', '7.3M', '9.1M', '55M',
#        '23k', '6.5M', '1.5M', '7.5M', '51M', '41M', '48M', '8.5M', '46M',
#        '8.3M', '4.3M', '4.7M', '3.3M', '40M', '7.8M', '8.8M', '6.6M',
# ...

# %%
##there values are 44k and 100m now we will have to remove these values
df_copy['Size'] = df_copy['Size'].str.replace("M","000")

# %%
df_copy['Size'] = df_copy['Size'].str.replace("k","")

# %%
df_copy['Size'].unique()
# Out:
# array(['19000', '14000', '8.7000', '25000', '2.8000', '5.6000', '29000',
#        '33000', '3.1000', '28000', '12000', '20000', '21000', '37000',
#        '2.7000', '5.5000', '17000', '39000', '31000', '4.2000', '7.0000',
#        '23000', '6.0000', '6.1000', '4.6000', '9.2000', '5.2000', '11000',
#        '24000', 'Varies with device', '9.4000', '15000', '10000',
#        '1.2000', '26000', '8.0000', '7.9000', '56000', '57000', '35000',
#        '54000', '201', '3.6000', '5.7000', '8.6000', '2.4000', '27000',
#        '2.5000', '16000', '3.4000', '8.9000', '3.9000', '2.9000', '38000',
#        '32000', '5.4000', '18000', '1.1000', '2.2000', '4.5000', '9.8000',
#        '52000', '9.0000', '6.7000', '30000', '2.6000', '7.1000', '3.7000',
#        '22000', '7.4000', '6.4000', '3.2000', '8.2000', '9.9000',
#        '4.9000', '9.5000', '5.0000', '5.9000', '13000', '73000', '6.8000',
#        '3.5000', '4.0000', '2.3000', '7.2000', '2.1000', '42000',
# ...

# %%
df_copy['Size'] = df_copy['Size'].str.replace('Varies with device',str(np.nan))

# %%
df_copy['Size'].unique()
# Out:
# array(['19000', '14000', '8.7000', '25000', '2.8000', '5.6000', '29000',
#        '33000', '3.1000', '28000', '12000', '20000', '21000', '37000',
#        '2.7000', '5.5000', '17000', '39000', '31000', '4.2000', '7.0000',
#        '23000', '6.0000', '6.1000', '4.6000', '9.2000', '5.2000', '11000',
#        '24000', 'nan', '9.4000', '15000', '10000', '1.2000', '26000',
#        '8.0000', '7.9000', '56000', '57000', '35000', '54000', '201',
#        '3.6000', '5.7000', '8.6000', '2.4000', '27000', '2.5000', '16000',
#        '3.4000', '8.9000', '3.9000', '2.9000', '38000', '32000', '5.4000',
#        '18000', '1.1000', '2.2000', '4.5000', '9.8000', '52000', '9.0000',
#        '6.7000', '30000', '2.6000', '7.1000', '3.7000', '22000', '7.4000',
#        '6.4000', '3.2000', '8.2000', '9.9000', '4.9000', '9.5000',
#        '5.0000', '5.9000', '13000', '73000', '6.8000', '3.5000', '4.0000',
#        '2.3000', '7.2000', '2.1000', '42000', '7.3000', '9.1000', '55000',
# ...

# %%
df_copy['Size'] = df_copy['Size'].astype(float) ##here we convert object datavalues to float data values

# %%
# using generic function
# def size_process(item):
#   if(str(item)[-1]=='M'):
#     res = float(str(item).replace('M',' '))
#     res = res*1000
#     return str(res)
#   elif(str(item)[-1]=='k'):
#     res = str(item).replace('k',' ')
#     return res
#   else:
#     return str(np.Nan)

# %%
df_copy['Size']
# Out:
# 0         19000
# 1         14000
# 2        8.7000
# 3         25000
# 4        2.8000
#           ...
# 10836     53000
# 10837    3.6000
# 10838    9.5000
# 10839       nan
# 10840     19000
# Name: Size, Length: 10840, dtype: object

# %%
df_copy['Installs']
# Out:
# 0            10,000+
# 1           500,000+
# 2         5,000,000+
# 3        50,000,000+
# 4           100,000+
#             ...
# 10836         5,000+
# 10837           100+
# 10838         1,000+
# 10839         1,000+
# 10840    10,000,000+
# Name: Installs, Length: 10840, dtype: object

# %%
df_copy['Installs'] = df_copy['Installs'].str.replace('+','').str.replace(',','')
# Out:
# <ipython-input-49-20e99ce1fe2f>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_copy['Installs'] = df_copy['Installs'].str.replace('+','').str.replace(',','')

# %%
df_copy["Installs"] = df_copy["Installs"].astype(int)

# %%
df_copy['Installs'].dtype
# Out:
# dtype('int64')

# %%
df_copy['Price']
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 10836    0
# 10837    0
# 10838    0
# 10839    0
# 10840    0
# Name: Price, Length: 10840, dtype: object

# %%
df_copy['Price'].unique()
# Out:
# array(['0', '$4.99', '$3.99', '$6.99', '$1.49', '$2.99', '$7.99', '$5.99',
#        '$3.49', '$1.99', '$9.99', '$7.49', '$0.99', '$9.00', '$5.49',
#        '$10.00', '$24.99', '$11.99', '$79.99', '$16.99', '$14.99',
#        '$1.00', '$29.99', '$12.99', '$2.49', '$10.99', '$1.50', '$19.99',
#        '$15.99', '$33.99', '$74.99', '$39.99', '$3.95', '$4.49', '$1.70',
#        '$8.99', '$2.00', '$3.88', '$25.99', '$399.99', '$17.99',
#        '$400.00', '$3.02', '$1.76', '$4.84', '$4.77', '$1.61', '$2.50',
#        '$1.59', '$6.49', '$1.29', '$5.00', '$13.99', '$299.99', '$379.99',
#        '$37.99', '$18.99', '$389.99', '$19.90', '$8.49', '$1.75',
#        '$14.00', '$4.85', '$46.99', '$109.99', '$154.99', '$3.08',
#        '$2.59', '$4.80', '$1.96', '$19.40', '$3.90', '$4.59', '$15.46',
#        '$3.04', '$4.29', '$2.60', '$3.28', '$4.60', '$28.99', '$2.95',
#        '$2.90', '$1.97', '$200.00', '$89.99', '$2.56', '$30.99', '$3.61',
# ...

# %%
df_copy['Price'] = df_copy['Price'].str.replace('$','')
# Out:
# <ipython-input-63-02d9076139cd>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_copy['Price'] = df_copy['Price'].str.replace('$','')

# %%
df_copy['Price'] = df_copy['Price'].astype(float)

# %%
df_copy['Price'].unique()
# Out:
# array([  0.  ,   4.99,   3.99,   6.99,   1.49,   2.99,   7.99,   5.99,
#          3.49,   1.99,   9.99,   7.49,   0.99,   9.  ,   5.49,  10.  ,
#         24.99,  11.99,  79.99,  16.99,  14.99,   1.  ,  29.99,  12.99,
#          2.49,  10.99,   1.5 ,  19.99,  15.99,  33.99,  74.99,  39.99,
#          3.95,   4.49,   1.7 ,   8.99,   2.  ,   3.88,  25.99, 399.99,
#         17.99, 400.  ,   3.02,   1.76,   4.84,   4.77,   1.61,   2.5 ,
#          1.59,   6.49,   1.29,   5.  ,  13.99, 299.99, 379.99,  37.99,
#         18.99, 389.99,  19.9 ,   8.49,   1.75,  14.  ,   4.85,  46.99,
#        109.99, 154.99,   3.08,   2.59,   4.8 ,   1.96,  19.4 ,   3.9 ,
#          4.59,  15.46,   3.04,   4.29,   2.6 ,   3.28,   4.6 ,  28.99,
#          2.95,   2.9 ,   1.97, 200.  ,  89.99,   2.56,  30.99,   3.61,
#        394.99,   1.26,   1.2 ,   1.04])

# %%
df_copy.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews             int64
# Size              float64
# Installs            int64
# Type               object
# Price             float64
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
##Now segrigate this data type Based on datatype
df_copy[df_copy.columns]
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
categorical_features  = [feature for feature in df_copy.columns if df_copy[feature].dtype == 'O']

# %%
df_copy[[feature for feature in df_copy.columns if df_copy[feature].dtype == 'O']]
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
##Integer datatype columns
[feature for feature in df_copy.columns if df_copy[feature].dtype == 'int64']
# Out:
# ['Reviews', 'Installs']

# %%
# float datatype column
[feature for feature in df_copy.columns if df_copy[feature].dtype == 'float']
# Out:
# ['Rating', 'Size', 'Price']

# %%
##Non categorical data
numerical_features = [feature for feature in df_copy.columns if df_copy[feature].dtype != 'O']

# %%
df_copy['Type'].unique()
# Out:
# array(['Free', 'Paid', nan], dtype=object)

# %%
df_copy['Type'].value_counts()
# Out:
# Free    10039
# Paid      800
# Name: Type, dtype: int64

# %%
import seaborn as sns
sns.countplot(x = df_copy['Type'])
# Out:
# <Axes: xlabel='Type', ylabel='count'>

# %%
df_copy['Content Rating']
# Out:
# 0          Everyone
# 1          Everyone
# 2          Everyone
# 3              Teen
# 4          Everyone
#             ...
# 10836      Everyone
# 10837      Everyone
# 10838      Everyone
# 10839    Mature 17+
# 10840      Everyone
# Name: Content Rating, Length: 10840, dtype: object

# %%
sns.countplot(x = df_copy['Content Rating']) ##Highest category of app for everyone
# Out:
# <Axes: xlabel='Content Rating', ylabel='count'>

# %%
sns.displot(df_copy['Price'])

# %%
sns.distplot(df_copy['Price'])
# Out:
# <ipython-input-97-1bf3d7e528a8>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_copy['Price'])
# <Axes: xlabel='Price', ylabel='Density'>

# %%
sns.histplot(df_copy['Price'])
# Out:
# <Axes: xlabel='Price', ylabel='Count'>

# %%
sns.displot(df_copy['Rating']) ##inights here is highest rating is 4.5

# %%
sns.kdeplot(df_copy['Rating'])
# Out:
# <Axes: xlabel='Rating', ylabel='Density'>

# %%
##what is the percentage of share of each category in all the app
df_copy['Category'].value_counts()
# Out:
# FAMILY                 1972
# GAME                   1144
# TOOLS                   843
# MEDICAL                 463
# BUSINESS                460
# PRODUCTIVITY            424
# PERSONALIZATION         392
# COMMUNICATION           387
# SPORTS                  384
# LIFESTYLE               382
# FINANCE                 366
# HEALTH_AND_FITNESS      341
# PHOTOGRAPHY             335
# SOCIAL                  295
# NEWS_AND_MAGAZINES      283
# SHOPPING                260
# TRAVEL_AND_LOCAL        258
# DATING                  234
# BOOKS_AND_REFERENCE     231
# VIDEO_PLAYERS           175
# EDUCATION               156
# ENTERTAINMENT           149
# MAPS_AND_NAVIGATION     137
# FOOD_AND_DRINK          127
# HOUSE_AND_HOME           88
# AUTO_AND_VEHICLES        85
# LIBRARIES_AND_DEMO       85
# WEATHER                  82
# ART_AND_DESIGN           65
# EVENTS                   64
# PARENTING                60
# COMICS                   60
# BEAUTY                   53
# ...

# %%
df_copy.info()

# %%
df_copy['Category'].value_counts().plot.pie(y = df_copy['Category'],autopct ='%1.1f%%',figsize =(12,12))
# Out:
# <Axes: ylabel='Category'>

# %%
##What is top 10 category of app
df_copy['Category'].value_counts()[:10]
# Out:
# FAMILY             1972
# GAME               1144
# TOOLS               843
# MEDICAL             463
# BUSINESS            460
# PRODUCTIVITY        424
# PERSONALIZATION     392
# COMMUNICATION       387
# SPORTS              384
# LIFESTYLE           382
# Name: Category, dtype: int64

# %%
#which category has the highest installation
df_copy.groupby(['Category'])['Installs'].sum().sort_values(ascending=False)
# Out:
# Category
# GAME                   35086024415
# COMMUNICATION          32647276251
# PRODUCTIVITY           14176091369
# SOCIAL                 14069867902
# TOOLS                  11452771915
# FAMILY                 10258263505
# PHOTOGRAPHY            10088247655
# NEWS_AND_MAGAZINES      7496317760
# TRAVEL_AND_LOCAL        6868887146
# VIDEO_PLAYERS           6222002720
# SHOPPING                3247848785
# ENTERTAINMENT           2869160000
# PERSONALIZATION         2325494782
# BOOKS_AND_REFERENCE     1921469576
# SPORTS                  1751174498
# HEALTH_AND_FITNESS      1583072512
# BUSINESS                1001914865
# FINANCE                  876648734
# EDUCATION                871452000
# MAPS_AND_NAVIGATION      724281890
# LIFESTYLE                537643539
# WEATHER                  426100520
# FOOD_AND_DRINK           273898751
# DATING                   264310807
# HOUSE_AND_HOME           168712461
# ART_AND_DESIGN           124338100
# ...

# %%
df_temp = df_copy.groupby(['Category','Type'])['Installs'].sum().sort_values(ascending = True).reset_index()

# %%
df_temp[df_temp.Category == 'GAME']
# Out:
#    Category  Type     Installs
# 29     GAME  Paid     21099965
# 62     GAME  Free  35064924450

# %%
##
